# %%
print("Hello World")
# Out:
# Hello World

# %%
import os

print(os.path.getsize("../data/superstore.csv"))
# Out:
# 0

# %%
import os
print(os.path.getsize("../data/superstore.csv"))
# Out:
# 0

# %%
import os

size = os.path.getsize("../data/superstore.csv")
print("File size:", size)
# Out:
# File size: 0
